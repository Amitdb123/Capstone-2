# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
os.getcwd()
# Out:
# 'C:\\Users\\Amit\\Desktop\\SPRINGBOARD PROJECTS\\Project-cap2'

# %%
os.chdir('C:\\Users\\Amit\\Desktop\\SPRINGBOARD PROJECTS\\Project-cap2\\data')
os.getcwd()
# Out:
# 'C:\\Users\\Amit\\Desktop\\SPRINGBOARD PROJECTS\\Project-cap2\\data'

# %%
os.listdir()
# Out:
# ['Adjusted close.csv', 'Moving_Average_Data.csv', 'Original_dataframe.csv']

# %%
MAD = pd.read_csv('Moving_Average_Data.csv')
ODF = pd.read_csv('Original_dataframe.csv')
ADJC = pd.read_csv('Adjusted close.csv')

# %%
ADJC = ADJC.set_index('Date')

ADJC.head()
# Out:
#                 Apple      Google         Hp  Microsoft       Sony
# Date
# 2010-01-04  26.419203  313.688690  18.160637  24.168472  27.184526
# 2010-01-05  26.464878  312.307312  18.236814  24.176279  27.057753
# 2010-01-06  26.043921  304.434448  18.067152  24.027906  27.030584
# 2010-01-07  25.995777  297.347351  18.074080  23.778025  26.985306
# 2010-01-08  26.168606  301.311310  18.209112  23.942017  27.537689

# %%
# %matplotlib inline
apple10 = ADJC['Apple'].rolling(window=10).mean()
apple30 = ADJC['Apple'].rolling(window=30).mean()
apple60 = ADJC['Apple'].rolling(window=60).mean()
apple_std10 = ADJC['Apple'].rolling(window=10).std()


_ = ADJC['Apple'].plot(figsize=(9,9),label='Daily')
_ = apple10.plot(label='Rolling 10 days')
_ = apple30.plot(label='Rolling 30 days')
_ = apple60.plot(label='Rolling 60 days')
_ = plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
_ = plt.legend()
_ = plt.title('Rolling Mean of Apple\'s Adjusted Close Price.')
_ = plt.ylabel('Price')
_ = plt.xlabel('Year')

# %%
# %matplotlib inline
google10 = ADJC['Google'].rolling(window=10).mean()
google30 = ADJC['Google'].rolling(window=30).mean()
google60 = ADJC['Google'].rolling(window=60).mean()

_ = ADJC['Google'].plot(figsize=(9,9),label='Daily')
_ = google10.plot(label='Rolling 10 days')
_ = google30.plot(label='Rolling 30 days')
_ = google60.plot(label='Rolling 60 days')
_ = plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
_ = plt.legend()
_ = plt.title('Rolling Mean of Google\'s Adjusted Close Price.')
_ = plt.ylabel('Price')
_ = plt.xlabel('Year')

# %%
# %matplotlib inline
hp10 = ADJC['Hp'].rolling(window=10).mean()
hp30 = ADJC['Hp'].rolling(window=30).mean()
hp60 = ADJC['Hp'].rolling(window=60).mean()

_ = ADJC['Hp'].plot(figsize=(9,9),label='Daily')
_ = hp10.plot(label='Rolling 10 days')
_ = hp30.plot(label='Rolling 30 days')
_ = hp60.plot(label='Rolling 60 days')
_ = plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
_ = plt.legend()
_ = plt.title('Rolling Mean of Hp\'s Adjusted Close Price.')
_ = plt.ylabel('Price')
_ = plt.xlabel('Year')

# %%
# %matplotlib inline
micro10 = ADJC['Microsoft'].rolling(window=10).mean()
micro30 = ADJC['Microsoft'].rolling(window=30).mean()
micro60 = ADJC['Microsoft'].rolling(window=60).mean()

_ = ADJC['Microsoft'].plot(figsize=(9,9),label='Daily')
_ = micro10.plot(label='Rolling 10 days')
_ = micro30.plot(label='Rolling 30 days')
_ = micro60.plot(label='Rolling 60 days')
_ = plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
_ = plt.legend()
_ = plt.title('Rolling Mean of Microsoft\'s Adjusted Close Price.')
_ = plt.ylabel('Price')
_ = plt.xlabel('Year')

# %%
# %matplotlib inline
sony10 = ADJC['Sony'].rolling(window=10).mean()
sony30 = ADJC['Sony'].rolling(window=30).mean()
sony60 = ADJC['Sony'].rolling(window=60).mean()

_ = ADJC['Sony'].plot(figsize=(9,9),label='Daily')
_ = sony10.plot(label='Rolling 10 days')
_ = sony30.plot(label='Rolling 30 days')
_ = sony60.plot(label='Rolling 60 days')
_ = plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
_ = plt.legend()
_ = plt.title('Rolling Mean of Sony\'s Adjusted Close Price.')
_ = plt.ylabel('Price')
_ = plt.xlabel('Year')

# %%
# Rolling mean of all companies with a window of 50 days. 
# %matplotlib inline
MAD.plot(x='Date',figsize=(9,7))
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.ylabel('Price')
plt.xlabel('Year')
plt.title('Comparison of Adjusted Closing Price of Technology Companies by a 50 Day Rolling Mean')
plt.show()

# %%
# convert Date into a datetime object for both df
ODF['Date'] = pd.to_datetime(ODF['Date'])
MAD['Date'] = pd.to_datetime(MAD['Date'])
ODF.info()
MAD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12860 entries, 0 to 12859
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          12860 non-null  datetime64[ns]
#  1   High          12860 non-null  float64
#  2   Low           12860 non-null  float64
#  3   Open          12860 non-null  float64
#  4   Close         12860 non-null  float64
#  5   Volume        12860 non-null  float64
#  6   Adj Close     12860 non-null  float64
#  7   company_name  12860 non-null  object
# dtypes: datetime64[ns](1), float64(6), object(1)
# memory usage: 753.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2572 entries, 0 to 2571
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2572 non-null   datetime64[ns]
#  1   Apple      2523 non-null   float64
#  2   Google     2523 non-null   float64
#  3   Hp         2523 non-null   float64
#  4   Microsoft  2523 non-null   float64
#  5   Sony       2523 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 120.6 KB

# %%
ODF.head()
# Out:
#         Date       High        Low       Open      Close       Volume  \
# 0 2010-01-04  30.642857  30.340000  30.490000  30.572857  123432400.0
# 1 2010-01-05  30.798571  30.464285  30.657143  30.625713  150476200.0
# 2 2010-01-06  30.747143  30.107143  30.625713  30.138571  138040000.0
# 3 2010-01-07  30.285715  29.864286  30.250000  30.082857  119282800.0
# 4 2010-01-08  30.285715  29.865715  30.042856  30.282858  111902700.0
#
#    Adj Close company_name
# 0  26.419203         AAPL
# 1  26.464878         AAPL
# 2  26.043921         AAPL
# 3  25.995777         AAPL
# 4  26.168606         AAPL

# %%
# the daily returns on closing price for each company 

close = pd.pivot_table(ODF,index='Date',values='Close',columns='company_name')
returns = close.pct_change()
returns = returns.drop(pd.Timestamp('2010-01-04'),axis=0) # drop NaN values from df
returns.head()
# Out:
# company_name      AAPL     GOOGL       HPQ      MSFT       SNE
# Date
# 2010-01-05    0.001729 -0.004404  0.004194  0.000323 -0.004664
# 2010-01-06   -0.015906 -0.025209 -0.009303 -0.006137 -0.001004
# 2010-01-07   -0.001849 -0.023280  0.000383 -0.010400 -0.001675
# 2010-01-08    0.006648  0.013331  0.007471  0.006897  0.020470
# 2010-01-11   -0.008822 -0.001512 -0.003042 -0.012720  0.006248

# %%
#Pairplot of all companies

import seaborn as sns
_ = sns.pairplot(returns,kind='reg')

# %%
# table showing the dates of maximum and minimum closing price by their date

max_min = dict()
close.head()

for com in close.columns:
    max_min[com] = [close[com].idxmin(),close[com].idxmax()]

df_max_min = pd.DataFrame(data=max_min,index=['min','max'])
df_max_min.head()
# Out:
#           AAPL      GOOGL        HPQ       MSFT        SNE
# min 2010-02-04 2010-07-06 2012-11-20 2010-06-30 2012-12-04
# max 2020-02-12 2020-02-19 2018-10-04 2020-02-10 2020-02-04

# %%
# table showing the mean and standard deviation of each company based on their daily returns 
mean_std = dict()

for com in returns.columns:
    mean_std[com] = [np.mean(returns[com]),np.std(returns[com])]

df_mean_std = pd.DataFrame(data=mean_std,index=['mean','std'])
df_mean_std.head()
# Out:
#           AAPL     GOOGL       HPQ      MSFT       SNE
# mean  0.000923  0.000598 -0.000002  0.000696  0.000434
# std   0.017128  0.015920  0.020472  0.015468  0.020714

# %%
#plot of histogram for each company with the mean and std.
# %matplotlib inline 
_ = plt.hist(returns['AAPL'],bins=15,histtype='step')
_ = plt.axvline(df_mean_std.loc['mean','AAPL'],color='red',linestyle='dashed',linewidth=1)
_ = plt.axvline(df_mean_std.loc['std','AAPL'],color='g',linestyle='dashed',linewidth=1)
_ = plt.axvline(-df_mean_std.loc['std','AAPL'],color='g',linestyle='dashed',linewidth=1)
_ = plt.xlabel('Daily Returns')
_ = plt.title('Apple')
plt.show()

# %%
# %matplotlib inline 
_ = plt.hist(returns['GOOGL'],bins=15,histtype='step')
_ = plt.axvline(df_mean_std.loc['mean','GOOGL'],color='red',linestyle='dashed',linewidth=1)
_ = plt.axvline(df_mean_std.loc['std','GOOGL'],color='g',linestyle='dashed',linewidth=1)
_ = plt.axvline(-df_mean_std.loc['std','GOOGL'],color='g',linestyle='dashed',linewidth=1)
_ = plt.xlabel('Daily Returns')
_ = plt.title('Google')
plt.show()

# %%
# %matplotlib inline 
_ = plt.hist(returns['HPQ'],bins=15,histtype='step')
_ = plt.axvline(df_mean_std.loc['mean','HPQ'],color='red',linestyle='dashed',linewidth=1)
_ = plt.axvline(df_mean_std.loc['std','HPQ'],color='g',linestyle='dashed',linewidth=1)
_ = plt.axvline(-df_mean_std.loc['std','HPQ'],color='g',linestyle='dashed',linewidth=1)
_ = plt.xlabel('Daily Returns')
_ = plt.title('HP')
plt.show()

# %%
# %matplotlib inline 
_ = plt.hist(returns['MSFT'],bins=15,histtype='step')
_ = plt.axvline(df_mean_std.loc['mean','MSFT'],color='red',linestyle='dashed',linewidth=1)
_ = plt.axvline(df_mean_std.loc['std','MSFT'],color='g',linestyle='dashed',linewidth=1)
_ = plt.axvline(-df_mean_std.loc['std','MSFT'],color='g',linestyle='dashed',linewidth=1)
_ = plt.xlabel('Daily Returns')
_ = plt.title('Microsoft')
plt.show()

# %%
# %matplotlib inline 
_ = plt.hist(returns['SNE'],bins=15,histtype='step')
_ = plt.axvline(df_mean_std.loc['mean','SNE'],color='red',linestyle='dashed',linewidth=1)
_ = plt.axvline(df_mean_std.loc['std','SNE'],color='g',linestyle='dashed',linewidth=1)
_ = plt.axvline(-df_mean_std.loc['std','SNE'],color='g',linestyle='dashed',linewidth=1)
_ = plt.xlabel('Daily Returns')
_ = plt.title('Sony')
plt.show()

# %%
#Heatmap showing correlation coeffcients 
fig, ax = plt.subplots(1, 1,figsize=(9,7))
_ = sns.heatmap(close.corr(),annot=True,linewidth=0.5)
_ = plt.title('Heatmap Showing Correlations Between Companies.')
_ = ax.set_ylabel('')
_ = ax.set_xlabel('')
